# %% [markdown]
# ## "M1" Tensorflow Install and Test
#
#
#
# https://developer.apple.com/metal/tensorflow-plugin/
# https://docs.nvidia.com/deeplearning/cudnn/latest/reference/support-matrix.html

# %%
# !python -m pip install --upgrade pip
# !python -m pip install tensorflow
# Out:
# Requirement already satisfied: pip in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (24.2)
# Requirement already satisfied: tensorflow in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.8.1)
# Requirement already satisfied: namex in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in d:\installedsoftware\anaconda3\envs\python-notebook\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)

# %%
import tensorflow as tf

# Check TensorFlow version
print("TensorFlow Version:", tf.__version__)

# List physical devices
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available:", len(physical_devices))

# Print device details
for device in physical_devices:
    print(device)
# Out:
# 2024-11-02 11:56:03.692448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-02 11:56:03.781010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-02 11:56:03.808700: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-02 11:56:03.980223: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-02 11:56:05.473662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TensorFlow Version: 2.17.0
# Num GPUs Available: 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730573767.668382    1940 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:02:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-02 11:56:07.827624: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import tensorflow as tf

print("NumPy version: ", tf.__version__)

tf.config.list_physical_devices('GPU')
print(tf.config.list_physical_devices('GPU'))
# Out:
# NumPy version:  2.17.0
# []

# %%
cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=1, batch_size=256)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
#  28557312/169001437 ━━━━━━━━━━━━━━━━━━━━ 7:35 3us/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 cifar = tf.keras.datasets.cifar100
# ----> 2 (x_train, y_train), (x_test, y_test) = cifar.load_data()
#       3 model = tf.keras.applications.ResNet50(
#       4     include_top=True,
#       5     weights=None,
#       6     input_shape=(32, 32, 3),
#       7     classes=100,)
#       9 loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/site-packages/keras/src/datasets/cifar100.py:63, in load_data(label_mode)
#      61 dirname = "cifar-100-python-target"
#      62 origin = "https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz"
# ---> 63 path = get_file(
#      64     fname=dirname,
#      65     origin=origin,
#      66     extract=True,
#      67     file_hash=(  # noqa: E501
#      68         "85cd44d02ba6437773c5bbd22e183051d648de2e7d6b014e1ef29b855ba677a7"
#      69     ),
#      70 )
#      72 path = os.path.join(path, "cifar-100-python")
#      73 fpath = os.path.join(path, "train")
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/site-packages/keras/src/utils/file_utils.py:309, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     307 try:
#     308     try:
# --> 309         urlretrieve(origin, download_target, DLProgbar())
#     310     except urllib.error.HTTPError as e:
#     311         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/urllib/request.py:268, in urlretrieve(url, filename, reporthook, data)
#     265     reporthook(blocknum, bs, size)
#     267 while True:
# --> 268     block = fp.read(bs)
#     269     if not block:
#     270         break
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/http/client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/http/client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/python-notebook/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:
