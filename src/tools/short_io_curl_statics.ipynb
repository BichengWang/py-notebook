# %%
import requests

url = "https://t.uber.com/mactl_shell_cnt"

# querystring = {"domain":"short.xyz","originalURL":"https://blog.short.io/safety/"}

headers = {
    'accept': "application/json",
    'authorization': "pk_ELZHBEB35zSxDsR0"
    }

response = requests.request("GET", url, headers=headers
#                             , params=querystring
                           )

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /dsw/snapshots/3577215c-cc5b-4654-9900-faef6a8514f2/python310/lib/python3.10/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File /dsw/snapshots/3577215c-cc5b-4654-9900-faef6a8514f2/python310/lib/python3.10/site-packages/urllib3/connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# ...

# %%
# !curl -X GET "https://t.uber.com/mactl_shell_cnt" -H "Authorization: pk_ELZHBEB35zSxDsR0" -H "Accept: application/json"
