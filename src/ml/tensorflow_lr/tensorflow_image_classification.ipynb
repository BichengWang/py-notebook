# %% [markdown]
# # Image classification
#
# https://www.tensorflow.org/tutorials/images/classification

# %% [markdown]
# ## Import Keras

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Setup memory to fix critical issue
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)

# %%
data_dir
# Out:
# WindowsPath('C:/Users/User/.keras/datasets/flower_photos')

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
PIL.Image.open(str(roses[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=179x240 at 0x226B1AE4C08>

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x226B1AEC488>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x209 at 0x226B1AE28C8>

# %%
PIL.Image.open(str(tulips[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335 at 0x226B1AF1608>

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Create a dataset

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ### Configure the dataset for performance

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Standardize the data

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.02886732 1.0

# %% [markdown]
# ## Create the model

# %%
num_classes = 5

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model compile and training

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
epochs=10

# %%
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 92/92 [==============================] - 7s 51ms/step - loss: 1.7497 - accuracy: 0.3164 - val_loss: 1.0622 - val_accuracy: 0.5450
# Epoch 2/10
# 92/92 [==============================] - 1s 12ms/step - loss: 1.0151 - accuracy: 0.5935 - val_loss: 0.9758 - val_accuracy: 0.6049
# Epoch 3/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.8452 - accuracy: 0.6727 - val_loss: 0.9128 - val_accuracy: 0.6322
# Epoch 4/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.6272 - accuracy: 0.7669 - val_loss: 0.9336 - val_accuracy: 0.6403
# Epoch 5/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.4485 - accuracy: 0.8532 - val_loss: 1.0528 - val_accuracy: 0.6431
# Epoch 6/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.2613 - accuracy: 0.9130 - val_loss: 1.1621 - val_accuracy: 0.6485
# Epoch 7/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1484 - accuracy: 0.9547 - val_loss: 1.2365 - val_accuracy: 0.6308
# Epoch 8/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1175 - accuracy: 0.9580 - val_loss: 1.5884 - val_accuracy: 0.6417
# Epoch 9/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.0579 - accuracy: 0.9851 - val_loss: 1.8914 - val_accuracy: 0.6403
# Epoch 10/10
# 92/92 [==============================] - 1s 12ms/step - loss: 0.0390 - accuracy: 0.9896 - val_loss: 1.8021 - val_accuracy: 0.6458

# %% [markdown]
# ### Model evaluation

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Overfitting

# %% [markdown]
# ### Data augmentation

# %% [markdown]
# Generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images.

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Visualize what a few augmented examples look like

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Dropout

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Recompile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_4 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 180, 180, 128)     3584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 90, 90, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 90, 90, 128)       147584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 45, 45, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 45, 45, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 22, 22, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 22, 22, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 61952)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               7929984
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 8,229,381
# Trainable params: 8,229,381
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 92/92 [==============================] - 12s 93ms/step - loss: 1.5335 - accuracy: 0.3867 - val_loss: 1.0998 - val_accuracy: 0.5463
# Epoch 2/50
# 92/92 [==============================] - 4s 45ms/step - loss: 1.0921 - accuracy: 0.5560 - val_loss: 1.0294 - val_accuracy: 0.5790
# Epoch 3/50
# 92/92 [==============================] - 4s 45ms/step - loss: 1.0069 - accuracy: 0.6022 - val_loss: 1.0226 - val_accuracy: 0.5954
# Epoch 4/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.9682 - accuracy: 0.6194 - val_loss: 0.9451 - val_accuracy: 0.6403
# Epoch 5/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.8548 - accuracy: 0.6687 - val_loss: 0.8935 - val_accuracy: 0.6649
# Epoch 6/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.7909 - accuracy: 0.6931 - val_loss: 0.8080 - val_accuracy: 0.6935
# Epoch 7/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.7468 - accuracy: 0.7243 - val_loss: 0.7996 - val_accuracy: 0.6935
# Epoch 8/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.7086 - accuracy: 0.7375 - val_loss: 0.7668 - val_accuracy: 0.7030
# Epoch 9/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.6731 - accuracy: 0.7471 - val_loss: 0.7246 - val_accuracy: 0.7180
# Epoch 10/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.6036 - accuracy: 0.7702 - val_loss: 0.7387 - val_accuracy: 0.7262
# Epoch 11/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.6672 - accuracy: 0.7501 - val_loss: 0.7564 - val_accuracy: 0.7153
# Epoch 12/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.6012 - accuracy: 0.7715 - val_loss: 0.6697 - val_accuracy: 0.7425
# Epoch 13/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.5871 - accuracy: 0.7713 - val_loss: 0.7085 - val_accuracy: 0.7330
# Epoch 14/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.5324 - accuracy: 0.7927 - val_loss: 0.6934 - val_accuracy: 0.7371
# Epoch 15/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.5056 - accuracy: 0.8143 - val_loss: 0.7039 - val_accuracy: 0.7480
# Epoch 16/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.5147 - accuracy: 0.7976 - val_loss: 0.8028 - val_accuracy: 0.7234
# Epoch 17/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.5263 - accuracy: 0.8107 - val_loss: 0.6755 - val_accuracy: 0.7616
# Epoch 18/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.4486 - accuracy: 0.8314 - val_loss: 0.6895 - val_accuracy: 0.7589
# Epoch 19/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.4099 - accuracy: 0.8537 - val_loss: 0.7364 - val_accuracy: 0.7316
# Epoch 20/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.4423 - accuracy: 0.8260 - val_loss: 0.6792 - val_accuracy: 0.7602
# Epoch 21/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.4162 - accuracy: 0.8349 - val_loss: 0.7372 - val_accuracy: 0.7616
# Epoch 22/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3645 - accuracy: 0.8630 - val_loss: 0.7473 - val_accuracy: 0.7616
# Epoch 23/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3639 - accuracy: 0.8745 - val_loss: 0.7689 - val_accuracy: 0.7411
# Epoch 24/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3494 - accuracy: 0.8718 - val_loss: 0.7692 - val_accuracy: 0.7371
# Epoch 25/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3394 - accuracy: 0.8753 - val_loss: 0.7652 - val_accuracy: 0.7480
# Epoch 26/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3070 - accuracy: 0.8878 - val_loss: 0.7955 - val_accuracy: 0.7452
# Epoch 27/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2984 - accuracy: 0.8833 - val_loss: 0.7796 - val_accuracy: 0.7452
# Epoch 28/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.3076 - accuracy: 0.8893 - val_loss: 0.7785 - val_accuracy: 0.7493
# Epoch 29/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2847 - accuracy: 0.9037 - val_loss: 0.7974 - val_accuracy: 0.7561
# Epoch 30/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2776 - accuracy: 0.8994 - val_loss: 0.8928 - val_accuracy: 0.7493
# Epoch 31/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2721 - accuracy: 0.9064 - val_loss: 0.9209 - val_accuracy: 0.7411
# Epoch 32/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2759 - accuracy: 0.9000 - val_loss: 0.9462 - val_accuracy: 0.7248
# Epoch 33/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2356 - accuracy: 0.9128 - val_loss: 0.8345 - val_accuracy: 0.7452
# Epoch 34/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2191 - accuracy: 0.9250 - val_loss: 0.8957 - val_accuracy: 0.7153
# Epoch 35/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2424 - accuracy: 0.9235 - val_loss: 0.8924 - val_accuracy: 0.7698
# Epoch 36/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2208 - accuracy: 0.9338 - val_loss: 0.8651 - val_accuracy: 0.7725
# Epoch 37/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1891 - accuracy: 0.9356 - val_loss: 0.9243 - val_accuracy: 0.7629
# Epoch 38/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1979 - accuracy: 0.9332 - val_loss: 0.8854 - val_accuracy: 0.7902
# Epoch 39/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1640 - accuracy: 0.9433 - val_loss: 0.9904 - val_accuracy: 0.7520
# Epoch 40/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1688 - accuracy: 0.9426 - val_loss: 0.9338 - val_accuracy: 0.7711
# Epoch 41/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1550 - accuracy: 0.9445 - val_loss: 1.0180 - val_accuracy: 0.7234
# Epoch 42/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1671 - accuracy: 0.9416 - val_loss: 1.0294 - val_accuracy: 0.7589
# Epoch 43/50
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1459 - accuracy: 0.9510 - val_loss: 1.0449 - val_accuracy: 0.7793
# Epoch 44/50
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1533 - accuracy: 0.9466 - val_loss: 1.0242 - val_accuracy: 0.7493
# Epoch 45/50
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1777 - accuracy: 0.9467 - val_loss: 1.0739 - val_accuracy: 0.7643
# Epoch 46/50
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1302 - accuracy: 0.9502 - val_loss: 1.0642 - val_accuracy: 0.7629
# Epoch 47/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1198 - accuracy: 0.9549 - val_loss: 1.0935 - val_accuracy: 0.7534
# Epoch 48/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1491 - accuracy: 0.9470 - val_loss: 1.0371 - val_accuracy: 0.7725
# Epoch 49/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1598 - accuracy: 0.9426 - val_loss: 1.1509 - val_accuracy: 0.7616
# Epoch 50/50
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1305 - accuracy: 0.9566 - val_loss: 1.2003 - val_accuracy: 0.7534

# %% [markdown]
# ### Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Predict on new data

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = keras.preprocessing.image.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to sunflowers with a 78.43 percent confidence.
